# %%
import pandas as pd 
allData=pd.read_csv('/Users/niveditaarvind/Desktop/governance_analytics/Deliverable 1/allData.csv')

# %%
allData.head()
# Out:
#     US States  Average Life Expectancy HS Degree % Bachelors Degree %  \
# 0     Alabama                     75.5       85.3%              24.5%
# 1      Alaska                     79.0       92.4%              29.0%
# 2     Arizona                     80.0       82.1%              28.4%
# 3    Arkansas                     76.0       85.6%              22.0%
# 4  California                     81.7       82.5%              32.6%
#
#   Advanced Degree % Median Household Income
# 0              9.1%                 $49,861
# 1             10.4%                 $74,346
# 2             10.7%                 $59,246
# 3              7.9%                 $47,062
# 4             12.2%                 $75,277

# %%
df1=allData

# %%
df1['HS Degree %'] = df1['HS Degree %'].str.rstrip('%').astype('float') / 100.0

# %%
df1['Bachelors Degree %'] = df1['Bachelors Degree %'].str.rstrip('%').astype('float') / 100.0

# %%
df1['Advanced Degree %'] = df1['Advanced Degree %'].str.rstrip('%').astype('float') / 100.0

# %%
df1
# Out:
#                US States  Average Life Expectancy  HS Degree %  \
# 0                Alabama                     75.5        0.853
# 1                 Alaska                     79.0        0.924
# 2                Arizona                     80.0        0.821
# 3               Arkansas                     76.0        0.856
# 4             California                     81.7        0.825
# 5               Colorado                     80.6        0.911
# 6            Connecticut                     80.9        0.902
# 7               Delaware                     78.5        0.893
# 8   District of Columbia                     79.0        0.903
# 9                Florida                     80.2        0.876
# 10               Georgia                     77.9        0.863
# 11                Hawaii                     82.3        0.916
# 12                 Idaho                     79.4        0.902
# 13              Illinois                     79.4        0.886
# ...

# %%
df1['Median Household Income'] = df1['Median Household Income'].replace({'\$': '', ',': ''}, regex=True)

# %% [markdown]
# df1

# %%
df1
# Out:
#                US States  Average Life Expectancy  HS Degree %  \
# 0                Alabama                     75.5        0.853
# 1                 Alaska                     79.0        0.924
# 2                Arizona                     80.0        0.821
# 3               Arkansas                     76.0        0.856
# 4             California                     81.7        0.825
# 5               Colorado                     80.6        0.911
# 6            Connecticut                     80.9        0.902
# 7               Delaware                     78.5        0.893
# 8   District of Columbia                     79.0        0.903
# 9                Florida                     80.2        0.876
# 10               Georgia                     77.9        0.863
# 11                Hawaii                     82.3        0.916
# 12                 Idaho                     79.4        0.902
# 13              Illinois                     79.4        0.886
# ...

# %%
alldatafinal = df1

# %%
alldatafinal= alldatafinal.to_csv('alldatafinal.csv',index=False)

# %%
alldatafinal=pd.read_csv("alldatafinal.csv")
alldatafinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   US States                51 non-null     object
#  1   Average Life Expectancy  51 non-null     float64
#  2   HS Degree %              51 non-null     float64
#  3   Bachelors Degree %       51 non-null     float64
#  4   Advanced Degree %        51 non-null     float64
#  5   Median Household Income  51 non-null     int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.5+ KB
